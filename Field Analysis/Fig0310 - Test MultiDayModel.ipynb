# %%
from mylib.statistic_test import *
from mylib.field.multiday_in_field import MultiDayInFieldRateChangeModel
from mylib.multiday.multiday import MultiDayLayout, MultiDayLayout2, MultiDayLayout3
from mylib.multiday.visualize.open_field import MultiDayLayoutOpenField
from mylib.multiday.core import MultiDayCore

code_id = "0310 - Test MultiDayModel"
loc = join(figpath, 'Field Analysis', code_id)
mkdir(loc)

# index_map = GetMultidayIndexmap(mouse=10224, stage='Stage 1+2', session=2, occu_num=2)
index_map = GetMultidayIndexmap(mouse=10227, stage='Stage 1+2', session=2, occu_num=2, f=f_CellReg_modi)
index_map[np.where(np.isnan(index_map))] = 0
index_map = index_map.astype(np.int64)

#cellnum = np.where(index_map == 0, 0, 1)
cellnum = np.where(index_map > 0, 1, 0)
cellnum = np.nansum(cellnum, axis=0)

dates = [ 20230806, 20230808, 20230810, 20230812, 
          20230814, 20230816, 20230818, 20230820, 
          20230822, 20230824, 20230827, 20230829,
          20230901,
          20230906, 20230908, 20230910, 20230912, 
          20230914, 20230916, 20230918, 20230920, 
          20230922, 20230924, 20230926, 20230928, 
          20230930] #[20230806, 20230808, 20230810, 20230812, 20230814, 20230816, 20230818, 20230820, 20230822, 20230824, 20230827, 20230829, 20230901],
        # 20230426, 20230428, 20230430, 20230502, 20230504, 20230506, 20230508,20230510, 20230512, 20230515, 20230517, 20230519, 20230521,
        # 20230703, 20230705, 20230707, 20230709, 20230711, 20230713,20230715, 20230717, 20230719, 20230721, 20230724, 20230726,20230728],
"""
for n in range(26, 1, -1):
    
    idx = np.where(cellnum == n)[0]
    print,(n, idx)
    mkdir(join(loc, '10227-Stage 1+2-Maze 1 [footprint]', str( n)+' Cells'))

    MultiDayLayout.visualize_cells(
        index_map=index_map,
        cell_pairs=idx,
        f=f1,
        #footprint_dirs=[os.path.join(r"E:\Data\Cross_maze\10227\Super Long-term Maze 1", 
        #                             "SFP"+str(date)+".mat") for date in dates],
        mouse=10227,
        maze_type=1,
        session=2,
        dates=dates,
        save_loc=join(loc, '10227-Stage 1+2-Maze 1 [footprint]', str(n)+' Cells'),
        is_show=False,
        loctimecurve_kwargs = {'bar_kwargs':{'markeredgewidth': 3, 'markersize': 5},
                               'line_kwargs':{'linewidth': 0.1, 'color': 'gray'}},
        layout_kw={"width_ratios": [2, 2, 10,1]}
    )
"""

# Reverse dates
# dates = [20230605, 20230606, 20230607, 20230608, 20230609, 20230613, 20230614, 20230615, 20230616, 20230617, 20230618, 20230619]
# dates = [20230613, 20230614, 20230615, 20230616, 20230617, 20230618, 20230619]
dates = [
    20240829, 20240831, 20240902, 20240904, 20240906,
    20240908, 20240910, 20240912, 20240914,
    20240916, 20240918, 20240920, 20240922,
    20240924, 20240926, 20240928, 20240930,
    20241002, 20241004, 20241006, 20241008,
    20241011, 20241013, 20241015, 20241017,
    20241019
]#[20231017, 20231018, 20231019, 20231020, 20231021, 20231022, 20231023]
mouse = 10234
with open(f_CellReg_modi['cellreg_folder'][12], 'rb') as handle:
    index_map = pickle.load(handle).astype(np.int64)

#cellnum = np.where(index_map == 0, 0, 1)
cellnum = np.where(index_map > 0, 1, 0)
cellnum = np.nansum(cellnum, axis=0)
print(index_map.shape)


for n in range(26, 15, -1):
    
    idx = np.where(cellnum == n)[0]
    if len(idx) == 0:
        continue
    print(n, idx)
    p = join(loc, f'{mouse}-MA', str(n)+' Cells')
    mkdir(p)


    """ 
    MultiDayLayout.visualize_cells(
        index_map=index_map,
        cell_pairs=idx,
        f=f4,
        #footprint_dirs=[os.path.join(r"E:\Data\Cross_maze\10227\Super Long-term Maze 1", 
        #                             "SFP"+str(date)+".mat") for date in dates],
        mouse=mouse,
        maze_type=3,
        session=1,
        dates=dates,
        save_loc=p,
        is_show=False,
        loctimecurve_kwargs = {'bar_kwargs':{'markeredgewidth': 0.75, 'markersize': 5},
                               'line_kwargs':{'linewidth': 0.1, 'color': 'gray'}},
        layout_kw={"width_ratios": [2, 2, 10,1]},
        paradigm='HairpinMaze',
        direction='cis'
    )
    """
    MultiDayLayout.visualize_cells(
        index_map=index_map,
        cell_pairs=idx,
        f=f1,
        #footprint_dirs=[os.path.join(r"E:\Data\Cross_maze\10227\Super Long-term Maze 1", 
        #                             "SFP"+str(date)+".mat") for date in dates],
        mouse=mouse,
        maze_type=1,
        session=2,
        dates=dates,
        save_loc=p,
        is_show=False,
        loctimecurve_kwargs = {'bar_kwargs':{'markeredgewidth': 0.75, 'markersize': 5},
                               'line_kwargs':{'linewidth': 0.1, 'color': 'gray'}},
        layout_kw={"width_ratios": [2, 2, 10,1]},
        paradigm='CrossMaze',
        #direction='trs'
    )
# Out:
#         D:\Data\FinalResults\Field Analysis\0310 - Test MultiDayModel is already existed!
# (26, 2994)
# 26 [  3  11  12  20  25  28  31  32  35  40  49  55  73 122 160 312]
#         D:\Data\FinalResults\Field Analysis\0310 - Test MultiDayModel\10232-HMP\26 Cells is already existed!
# [array([547], dtype=int64), array([553], dtype=int64), array([559], dtype=int64), array([565], dtype=int64), array([571], dtype=int64), array([577], dtype=int64), array([583], dtype=int64), array([589], dtype=int64), array([595], dtype=int64), array([601], dtype=int64), array([607], dtype=int64), array([613], dtype=int64), array([619], dtype=int64), array([625], dtype=int64), array([633], dtype=int64), array([641], dtype=int64), array([649], dtype=int64), array([657], dtype=int64), array([665], dtype=int64), array([673], dtype=int64), array([681], dtype=int64), array([689], dtype=int64), array([697], dtype=int64), array([705], dtype=int64), array([713], dtype=int64), array([721], dtype=int64)]
#     File Indices:  [547 553 559 565 571 577 583 589 595 601 607 613 619 625 633 641 649 657
#  665 673 681 689 697 705 713 721]
#     Getting trace...
# 100%|██████████| 26/26 [00:08<00:00,  2.99it/s]
# Cell Indices:  [ 44 238 139 410 249 268 300 213 211 118 377 244 139  89 128 203 103 102
#  194  61 233  87 157 198 158 187]
#    0/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [113  99 239 363 365 401 284 254 432 385 315 219 237 164 166 195 141 289
#  288 239 279 106 121 258 199 145]
#    1/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [295 150 263 359 364 305 263 418 182 208 171 103   8  29  25  93  22  55
#  178  96 203 142 183 214 192 165]
#    2/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [297 191  86  12   4  12  17 310 269 257 152 192 224 180 308 316 239  73
#   13 178  65  78  79 143 167  68]
#    3/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [252 448 241 208 164  15  25 525 281 149  84 113 148 169 276  95 116  34
#   40 200  34   8   5   3   6  22]
#    4/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [ 13 173  89 340  45 123  35 350  96  35  16  39  89  78 134 198 182 198
#  243 124 112  64  99 215 202  85]
#    5/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [218 353  49  67 277  85  26 449 377 120 156 171 250 289 311 290 319 301
#  144 188  88  77  28  93  38   5]
#    6/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [263  58 164 225 626 395 462 182 430  59 364 257 166  65  64  19  72 157
#  318 163 403 391 395 200 128  86]
#    7/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [164  42 157 300 381 367 331  78 198 144 370 333 211 133 259 280 257 241
#  322 115 354 325 381 173 296 208]
#    8/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [239 325 454 404 452 527 498 408 382 198 382 345 258 350 213 292 334 243
#  349 261 328 281 325 378 321 337]
#    9/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [390 423 323 465 542 472 508 124 383 276 461 344 287 296 309 244 211 138
#  290 187 335 417 472 399 455 395]
#    10/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [192 292 419 432 487 391 394 210 267 134 398 338 320 242 277 281 265 272
#  341 317 363 283 270 266 344 366]
#    11/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [243 109  46  32 191   6  11   4  12  19  61  30 172  70 179 114 190  84
#   59  58  15  18  18  41  75  25]
#    12/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [374 209 271 366 292 335 352  50 168  68 297 210  88  67  62  39 195  40
#   70  37 135  96 155 110 133 181]
#    13/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [320 290 318 347 180 417 261 316 551 244 180  46 200 149 140 101 150 152
#  115 270 198 144 238 163 201 120]
#    14/16, cell num = 26
#     Plot over, saving figure...
# Cell Indices:  [282 282 402 378 395 382 384 416 333 319 449 242 147 219 247 172 216 288
#  297 281 322 143 227 246 331 262]
#    15/16, cell num = 26
#     Plot over, saving figure...
# 25 [  0   1   2   6   7  15  16  18  19  22  29  30  33  34  37  38  47  50
#   61  64  74  75  77  79  81  83  84  94  97 120 124 131 133 135 137 143
#  155 190 266]
#         D:\Data\FinalResults\Field Analysis\0310 - Test MultiDayModel\10232-HMP\25 Cells is already existed!
# [array([547], dtype=int64), array([553], dtype=int64), array([559], dtype=int64), array([565], dtype=int64), array([571], dtype=int64), array([577], dtype=int64), array([583], dtype=int64), array([589], dtype=int64), array([595], dtype=int64), array([601], dtype=int64), array([607], dtype=int64), array([613], dtype=int64), array([619], dtype=int64), array([625], dtype=int64), array([633], dtype=int64), array([641], dtype=int64), array([649], dtype=int64), array([657], dtype=int64), array([665], dtype=int64), array([673], dtype=int64), array([681], dtype=int64), array([689], dtype=int64), array([697], dtype=int64), array([705], dtype=int64), array([713], dtype=int64), array([721], dtype=int64)]
#     File Indices:  [547 553 559 565 571 577 583 589 595 601 607 613 619 625 633 641 649 657
#  665 673 681 689 697 705 713 721]
#     Getting trace...
# 100%|██████████| 26/26 [01:01<00:00,  2.35s/it]
# Cell Indices:  [220 135   0 463 201 376 262  54 315 129 204 172 110 141  43 158 146  61
#   57  57 159 147 235 124 184 150]
#    0/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 305 153 345  73 231 141 202  91  78 186 208 146 163 148 230 132 189
#  109  83   3   2 108 139 284 349]
#    1/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 340 355 510 607 186 236 527 143 158 220   1  23  24   5  14   7  12
#   62   6  50  31 104 100 140 169]
#    2/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [269  45 235 379 226 132 128 348 128 331 240  59 132 193  53  51  78 175
#    0 102 129  83  84  30  39  66]
#    3/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [378  69 132 275 332 317 250 244 188 323 242 221 274   0 104  92  97   6
#   75   5 158 174 275 368 379 137]
#    4/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [129 194 284 236 432 240 312 305   0 325 332 122  42  12  42  28  29  31
#  101   3  98  40  43  37  28  16]
#    5/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 215 339 273 577 442 410 336 246 148 456 422 360 282  67 166 245 294
#  303 248 429 436 429 274 411 314]
#    6/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 264 374 113 205  74 483 521 464 406 285 189 182 183 117 176  94  50
#  164  63 230 170 289 195 210 193]
#    7/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 392  32  51  25 217 185 142  49 234 120 114 245 213 322 269 188 105
#  152 193  24   4  39  20  27  84]
#    8/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 192 307 317 231 212 154  93 116 169 198 270 107 121 113 107 115 119
#  173 238 268  51 218 338  93  71]
#    9/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [ 94 373  65  56 372 121  31 214  25 186  21  50  53  81   0  57 179 118
#  135 151 192 157 144 252 282 161]
#    10/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [210  87  33   9   7  10   5  53  69   0  64 109  14   5 103 156 156 156
#  147  97  27  26  61 161 237 284]
#    11/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [315   5  21  62 518 236 198 545 147 384  32  36  39  80  87  78   0 397
#   25 137 240 291 349 314  56  15]
#    12/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [338  11  68 169 469 171 273  66  55 189 162  49  21  17  79   0  11   3
#   55   4  73  33  48   8  20  13]
#    13/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 258 455 392 608 297 464 224 572 351 334  69  51 230 130  83 109  15
#   65  51  58  30  62  62 103  33]
#    14/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 308 383 493 443 313 463 227 220 436 464 381 307 354 365 323 294 141
#  365  71 344 220 240 239 209 202]
#    15/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 453 479 408 383  19 427 360 475 489 225 230 375 309 428 182 316 127
#   97 253 101  24  80  28   5  11]
#    16/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 310 131  54  30  34  29  75   7 285  76 118  56 179 233 277 281 219
#  125 164 141  25 152  90  96 124]
#    17/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 143 119 223 281 219 270 289 208 197  95 226  81 224 105  67 168  57
#  258  72 205  95  85 129 100  98]
#    18/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 366  50 149  41 154  63 139  40  90 114  71  73  22  38  69  35  65
#   16   2   2  29  24  17  36  12]
#    19/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 287 426 443 535 371 499 257 485 255 495 489 371 264 368 400 368 221
#  366 286 439 425 326 208 359 445]
#    20/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 413 540 327 485 140 184  46 130  63 419 343 317 129  20   5 104 144
#  193 147 257 401 161 209 225 321]
#    21/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [337   0  45  46 298  77 129 275 250  25  28 130 130 178 224 110 191 260
#   84  91  55  35  47  89  57  80]
#    22/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [259  60 120 237  15 185  72  23  62   1  22  72  85 159  18  16  15 109
#  168 233 160  47   0  51   8 251]
#    23/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 306 166 295 517 245 469 653 597 543 324 334 169 388 474 477 438 400
#  411 450 400 450 371 271 406 415]
#    24/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 187 407 415 463 270 253  32 200  17 153 106 100 120  95 128 249  94
#  154  49 337 230 236 244 326 289]
#    25/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 280 388 438 458 369 420  29 237  71 435 411 276 229 141 146 226 125
#  242 266 377 381 229 191 304 303]
#    26/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0  34  95 140 323 409 387 100 359 275 261  79 104 152  63  85 106 155
#   58 138  80  46 100 106  22  41]
#    27/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [391 218 362 467 402   0 373  20 213  76 248 297 223 205 188 241 263 231
#  291 111 468 199 165 149 194 131]
#    28/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [184   0 161 137 355  93  85 155  31  83  36  21  12 100 106   1  88  25
#   66  32   7  21  17  18  81 106]
#    29/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [111 147 147 478 304 205 293   0 270 297 487 140 212 211 263 174 229 196
#  314 185 360 190 311 370 218 126]
#    30/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 369  57  40  10  81  86 332   5  51  83  11  66 143 119 171 172 211
#  256 120  66 197  53  53 131  19]
#    31/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 458 555 229  87 174 173 523 610 451 289 404 328 368 422 334 337 346
#  331 305 373 192 375 394 247 347]
#    32/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 125 186 166 128  95 187 299  22  11  71  47   1   2 211 288 255 185
#   21 167 255 333 219 137 256 342]
#    33/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [ 66 376  15   1  50  14   8   9   1  22  25   0 129  90 155 118  73  14
#   42  41 223  88 209  82  63  32]
#    34/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 244 172 130 483  42  49  88  11 224  39 151 162 214 190  34 246 312
#  153 294 364 309 343 328 430 412]
#    35/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0  37 125 167 212 319 230 208 131 112  89 107 122 111  94 184 135 255
#  210  65 102  74 177  70 127 103]
#    36/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 322 191  87 114  53  19 281 231 265  14  16 120  60  84  56 136  71
#   87  34  49  45 115 248 187 245]
#    37/39, cell num = 25
#     Plot over, saving figure...
# Cell Indices:  [  0 224 392 482 537 173 291 186 471 424 241 204 116 122 118  32  69  66
#  130  59 171 148 294 115 220 294]
#    38/39, cell num = 25
#     Plot over, saving figure...
# 24 [  4   5   8  21  45  48  51  52  63  67  98 110 121 125 130 132 134 161
#  170 171 172 178 207 253 302]
#         D:\Data\FinalResults\Field Analysis\0310 - Test MultiDayModel\10232-HMP\24 Cells is made up successfully!
# [array([547], dtype=int64), array([553], dtype=int64), array([559], dtype=int64), array([565], dtype=int64), array([571], dtype=int64), array([577], dtype=int64), array([583], dtype=int64), array([589], dtype=int64), array([595], dtype=int64), array([601], dtype=int64), array([607], dtype=int64), array([613], dtype=int64), array([619], dtype=int64), array([625], dtype=int64), array([633], dtype=int64), array([641], dtype=int64), array([649], dtype=int64), array([657], dtype=int64), array([665], dtype=int64), array([673], dtype=int64), array([681], dtype=int64), array([689], dtype=int64), array([697], dtype=int64), array([705], dtype=int64), array([713], dtype=int64), array([721], dtype=int64)]
#     File Indices:  [547 553 559 565 571 577 583 589 595 601 607 613 619 625 633 641 649 657
#  665 673 681 689 697 705 713 721]
#     Getting trace...
# 100%|██████████| 26/26 [02:54<00:00,  6.71s/it]
# Cell Indices:  [  0  10 118 218 333 455 434  67 363 212 397 384 312   0 174 293 227 153
#  259 212 251 300 260 132 164 142]
#    0/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0  22 286   0 588  26  71 170 171 352  72  48  99  48 229 102  58  99
#   26 143  78 277  37  12  40  14]
#    1/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0 261 412 457 481   0 570 302 515 364 465 415 419 383 360 378 410 411
#  560 449 527 470 404 442 396 382]
#    2/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0   0 282  39   9   9  33  80  65  49   4   8 102 216 171  37 160  48
#    1  50  59  56  11   6  17  47]
#    3/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0   0  17  16 560  40 191  85  16  85  82  87 192 341 381 233 330 251
#  250 356  57  60  12  25  44  36]
#    4/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0 170 314 504   0 315 486 522 316 344 323 228 137  66 147  66  32  46
#  157 166 235 214 342 376 310 135]
#    5/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0   0   1   8 501 176 396 570 127 105   9  82 302 303 442 390 422 303
#  206 323 200 336 166  98  55  63]
#    6/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0 160 252 337 416   0 489 259 406 216 404 351 244 234 316 369 346 214
#  412 292 347 232 362 227 270 218]
#    7/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0 230 336 326 512 196 180 103 193 131 202   0 111 223  80 262  53  22
#   82  90 272 268 221 300 294 206]
#    8/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [403 359 141  74 130   0 101 130  73  28 317  84 105  62  96 141   0 217
#  180  69  60  44 130  92 110  35]
#    9/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [191 242 397 396 382   0 452 131 378 220 360 317 259 259 341 297 340 282
#  435 329 397 438 336   0 288 413]
#    10/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0   2  24  52 540 101 131  90 161 250 205 115 335 400 154  45  42 131
#  116 192 321 368 318 243 276   0]
#    11/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0   0 327 148  34  43 156 354 101  10  47   5  13   3   1  15  67  59
#   33  18  63  41  65  46 206 157]
#    12/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0 164 211 206 426 386 428 583 431 282  44  61   0  15 161 217  91  19
#    9  47  71 132  70 151 313 283]
#    13/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0 293 328 136 534  23  47 359 115 311 230 300 416   0 451 406 374 408
#  324 419 177 234 133 112 166 223]
#    14/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0 442 519  35   0 242 359  24   2   3  17  63 101 192  54 129 235 111
#   14   7  48 400 389 352 289 195]
#    15/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0 501  29   2  43  55  65 157 111 226 170 152 202 294 338 276 292 204
#  185 250   0  13   3  10   3   1]
#    16/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [273   0  19   0 587  17   7 285  67 113 122  42  86 261 294 270 285 280
#  171 215 150 177 256 140 188 154]
#    17/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0 270 251 320 562 224 155 163 197 258 365   0 329 222 151  18  36  89
#  200 195 296 365 307 278 259 328]
#    18/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0 368 381 334 348 158 362 477 293   0  66  90 153  98  82 238 176  74
#  108  98 216 203  81 181 348 222]
#    19/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0   0 413 192  55 204  42 314 190  30 124  44 114  39   9  33 181  64
#  177  15  61  43 113 125  98  52]
#    20/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0   0 159  82 169  32  15  86  53  32  26  73  72  92  27  11  21  13
#    2  12  18   6  27   4   4   7]
#    21/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [215 172 345  92 174 330 122 427 185  67 126   0   0   9 235  64  40  47
#  124 170 169 171 139 146 154 108]
#    22/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [  0   0 306 104 216 304 336 162 416 102 160 155 144 151 270 106 142  62
#  117  60  47  52 101 147 104 153]
#    23/25, cell num = 24
#     Plot over, saving figure...
# Cell Indices:  [ 98   0   0 384 134 199 118 120 102 167 105  26  32  32  55 148  76 133
#  127  78 127  34 296 359 433 147]
#    24/25, cell num = 24
#     Plot over, saving figure...
# 23 [ 10  13  14  17  23  24  26  27  39  44  54  56  57  66  69  72  91  93
#  103 109 117 144 163 176 181 186 209 221 363]
#         D:\Data\FinalResults\Field Analysis\0310 - Test MultiDayModel\10232-HMP\23 Cells is made up successfully!
# [array([547], dtype=int64), array([553], dtype=int64), array([559], dtype=int64), array([565], dtype=int64), array([571], dtype=int64), array([577], dtype=int64), array([583], dtype=int64), array([589], dtype=int64), array([595], dtype=int64), array([601], dtype=int64), array([607], dtype=int64), array([613], dtype=int64), array([619], dtype=int64), array([625], dtype=int64), array([633], dtype=int64), array([641], dtype=int64), array([649], dtype=int64), array([657], dtype=int64), array([665], dtype=int64), array([673], dtype=int64), array([681], dtype=int64), array([689], dtype=int64), array([697], dtype=int64), array([705], dtype=int64), array([713], dtype=int64), array([721], dtype=int64)]
#     File Indices:  [547 553 559 565 571 577 583 589 595 601 607 613 619 625 633 641 649 657
#  665 673 681 689 697 705 713 721]
#     Getting trace...
# 100%|██████████| 26/26 [03:59<00:00,  9.22s/it]
# Cell Indices:  [  0   0 367 304   0  51  73 269  99 161  78 128 220 241 310 250 389 129
#  148 288 173 271  38  21  59  74]
#    0/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0  78 123   0   0 434 432 346 298 442 311 239 170  61 136 149  98  43
#  160  28 179 208 293 279 196 346]
#    1/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 122 156 292 583 342 376  99 256 213   0   0 342 332 210 188 210 159
#  396 103 435 178 447 363 446 301]
#    2/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 256 448 494   0 626 607 573 644 415   0 491 431 392 465 521 456 370
#  528 416 562 460 485 456 435 387]
#    3/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0   0 538 298   0 172 297 532 373 349 376 378 253 249 398 274 233 262
#  343 361 297 204  71 226  88 196]
#    4/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0   0 275  33   0  91  45 141  34 103  31  22 124 182 275 219 121  83
#   23 210   8 104 105 192  77 109]
#    5/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 144 264 332 430 400 306 334 350 126 306 176 126 162 126   0   0  20
#  102   9 246 107 123 156 112  82]
#    6/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0  68 311 439   0 533 618 207 368 242 466 454 397   0 386 363 380 297
#  511 414 536 501 473 434 472 422]
#    7/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 309 546 399   0 229 249  83   0 277 390 387 291 304 254 231 278 194
#  274 207 341 347 234 184 216 273]
#    8/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 503 525 525   0 566 450 278 438 195 433 406 358 238 328 247 273 351
#  464 486 501   0 475 418 242 327]
#    9/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 137 178 322 247 184 144 153 132 329  48  54  24 108  97 164   0 176
#  327   0 215 352 328 281 163  81]
#    10/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [213 121 343 138 470 425 423 320   0 289 290   0 157 228   0 162 120 257
#  293 247 269 273 103 128 179 167]
#    11/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [314  83 214 172 246 125 443   0  71  34  55  81  34   4  73   0 118  58
#  113  88 237 248 211   0  78  88]
#    12/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 449 493 385   0   0 535 650 615 470 409 373 311 376 435 446 460 372
#  460 409 444 404 304 342 328 364]
#    13/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0   0 433 143 627  62 133 450 309 342   0 322 377 452 438 384 361 450
#  416 452 334 459 107  75  97 175]
#    14/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0  10  44   5  69  18 145  36  92  67 229  76 177  74  51  38
#    5  94 245 226 249 301 291 166]
#    15/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [166 139 207 267  90 426 245 194 247 267 363   0 289 206 307 260 289 254
#  325 119   0 221 255 354   0 258]
#    16/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [355   0 102  20   3 108  13  60  38 172  62 101 119 167 223 163   0 247
#  217   0  26  12  15 148 169 114]
#    17/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 497 453 484 654 457 642 670   0 542 451 374 305 253 358 356 317 210
#    0 262 271 305 334 295 311 191]
#    18/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0   0  70   0 442 262 419 502 458 401 214 286 316 380 418 485 455 317
#  386 402 197 376 290 221 190 219]
#    19/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 433 531 512   0 488 589 411 502 392 522 490 466 437 481 452 449 454
#  536 479 568   0 549 470 516 515]
#    20/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 177  27  91 406 259  34  81  17  33 135  52 142 155   0 130  44   0
#    6 101  16  11  19  23  42  38]
#    21/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [304   0   0   0 409 379 227 319 341 211 438 190 131 154  92 159 145 106
#  129  89 238  66 158  69 152 132]
#    22/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [358   0 526 356 478  82 138 323 180 360 116  40  78 112 207   0   0  53
#   44 181  29  68 348 384 437 252]
#    23/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0   0 475 405  72 107  81 537 537   0 197 249 134 172 306 207 171 110
#  122 206  90 153 198 355 261 212]
#    24/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0 460 145  28 578 273 207 531 587 421 286 321   0 407 449 393 356 304
#  299 407 330   0 181 189 147 129]
#    25/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [326   0  77 106 303 269 226 112  24 115 210 131 193 260 305 187  62 274
#   99   0   5 187   0  73  89  78]
#    26/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [121   0  73 153 140 211 212   0 157 140  79   0  68  74  36 139 111 165
#  133  24 133 100 184 126 153 188]
#    27/29, cell num = 23
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0 381 334 241 322  38 194 124 378 288 319 231 245 329 280 239
#  237 338 311 200 282 194 308 278]
#    28/29, cell num = 23
#     Plot over, saving figure...
# 22 [ 36  41  42  43  46  53  59  60  62  65  70  76  88  90  96 102 107 112
#  140 157 174 180 183 187 189 213 269 410 424 425 444]
#         D:\Data\FinalResults\Field Analysis\0310 - Test MultiDayModel\10232-HMP\22 Cells is made up successfully!
# [array([547], dtype=int64), array([553], dtype=int64), array([559], dtype=int64), array([565], dtype=int64), array([571], dtype=int64), array([577], dtype=int64), array([583], dtype=int64), array([589], dtype=int64), array([595], dtype=int64), array([601], dtype=int64), array([607], dtype=int64), array([613], dtype=int64), array([619], dtype=int64), array([625], dtype=int64), array([633], dtype=int64), array([641], dtype=int64), array([649], dtype=int64), array([657], dtype=int64), array([665], dtype=int64), array([673], dtype=int64), array([681], dtype=int64), array([689], dtype=int64), array([697], dtype=int64), array([705], dtype=int64), array([713], dtype=int64), array([721], dtype=int64)]
#     File Indices:  [547 553 559 565 571 577 583 589 595 601 607 613 619 625 633 641 649 657
#  665 673 681 689 697 705 713 721]
#     Getting trace...
# 100%|██████████| 26/26 [05:30<00:00, 12.70s/it]
# Cell Indices:  [  0 184 290 328   0 543 591 265 583 457 454 442 399   0 132   0 221 116
#  219 113 259 186 274 169 130 173]
#    0/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0 344 429 488   0 514 553 343 498 316 445 466 438 444 479 506   0 493
#  487 433 541   0 541 527 526 498]
#    1/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0 387 380 421 609 298   0 333 160 480 245 293   0   0 380 415 407 188
#   50 204  77 298 120 177 316 389]
#    2/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0 483 582   0   0 513 371  34 155 178   0 471 271 266 352 349 385 366
#  489 378 482 475 492 416 481 311]
#    3/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [242   0 227  59  47 288 228 459 255 207   0  12   3  51 258 273   0 145
#  267 278 165 270 192 283   0 340]
#    4/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0 618 475 444 395 433 347 411 166 187 156 123 254 173  72
#  263  43 250 127 223 202 335 319]
#    5/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0  25 137 213 290  99 109 150 459  31  12  28 115  28  44  43  13  82
#  281 108   0 259 128   0 254   0]
#    6/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0 105 148 204 354 482 484   0 484   0   0 203 232 263 178 170 228 235
#  126 145 228 225 297 212 205 264]
#    7/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0 146 222 324 648 495 544 364 287 397 494   0   0   0 348 314 189 307
#  382 348 475 418 344 360 262 411]
#    8/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0 391 516   0   0 427 582 397 564 418 476 492 435 412 459 501 467 446
#  533   0 539 464 482 478 462 418]
#    9/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0 141 349 178 590 499   0 176   0 308 346 290 234 307 246 212   0 162
#  351 152 260 278 207 121 107 210]
#    10/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0 638 113  89 405 229  81  51  15  40  56 127  38  41  37
#  106 126 244  55  64  97 108 353]
#    11/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [ 24 263 113  19 227   0 304 286 233 232  87  74  63  42  41 190   0 181
#    0 162 140 250 353 182 186   0]
#    12/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [103   0   0   0   0 373 316 475 336 176 227 267 206 181 205 173  96 113
#   64 129 214 131 327 166 333 238]
#    13/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0 128  84 168  19 402   0 345 195 339 265 225 204   0   0 201 234 316
#  271  70 114 145 203 232 118 194]
#    14/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0 486 443 400 505 450 525   0 642 493 275 369 351 415 452 442   0   0
#  454 384 410 445 496 259 339 329]
#    15/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0 542 290   0 439 333 246 280 320 386 314 297 239   0 239 169 130
#  270 161 213 167 145  79  48  31]
#    16/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0 625  57 224 622 596 535 361 217 315 391 443 331 345 476
#  251 310 355 251 135 302 404 217]
#    17/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0 317  59  23 298 481 293  52  96 238 406 423 383 293 318
#   45 232 273 422  60  33  31 240]
#    18/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [122   0   0   0  11 152 134 287  90  45  50 136  87  87  48 249 186 149
#  287 122 153 154 138 256 342   0]
#    19/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0 452  73 315 147 111 349  45 221  59 150 149 197 209  80  70   0
#  298   0  31 111   2 158 363 406]
#    20/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0 282 127  69  53  79 153 146   0  43  20 124  40  62  50  63
#  121  95 187 369 279 273 236  70]
#    21/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0 247 252 100 138  83 365 325 163  90  38  83 106  23  94   8  21
#   36  30  62 205 300   0 197   0]
#    22/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0 628 589 556 322 680 431 447 368 174 272 269 388 351 263
#  362 241 497 486 428 347 416 450]
#    23/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0  39  24 206  36 117 380 344 378 263 361 357   0 421 398 382 292
#  182   0 303 406 174  31  21  96]
#    24/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0  77  85 110   0   0 290   0 526 299 144 153 123 102  93  44  63  78
#  139 171 132 227 178 123  62  23]
#    25/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0 420 551   0 449 182   0 282 187   0  88 149  58 113 234  82 144  97
#   52  52 227 269 191 285 200 275]
#    26/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [290   0   0   0   0 210 310 560 561 327 147  85  15  20  46  71  27  70
#  172 140  56  57 160  39 378  17]
#    27/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [324   0   0   0 380   0 338 263 424 135 271 202 158 115 250 307 295 261
#  398 345 368 229 117 134 144 312]
#    28/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [333   0   0 131   0  39  82 169  48 107 161 173 177 236 304 218 209 245
#  191 308   0 215  86  65  90 199]
#    29/31, cell num = 22
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0 311 351  87  74 434 436 398   0 108 195 171 257 197 301 147
#  216 172 116  70 154  34  43  99]
#    30/31, cell num = 22
#     Plot over, saving figure...
# 21 [ 71  78  80  82  85  87  95 101 118 119 139 141 152 154 173 175 191 222
#  293 306 375 387]
#         D:\Data\FinalResults\Field Analysis\0310 - Test MultiDayModel\10232-HMP\21 Cells is made up successfully!
# [array([547], dtype=int64), array([553], dtype=int64), array([559], dtype=int64), array([565], dtype=int64), array([571], dtype=int64), array([577], dtype=int64), array([583], dtype=int64), array([589], dtype=int64), array([595], dtype=int64), array([601], dtype=int64), array([607], dtype=int64), array([613], dtype=int64), array([619], dtype=int64), array([625], dtype=int64), array([633], dtype=int64), array([641], dtype=int64), array([649], dtype=int64), array([657], dtype=int64), array([665], dtype=int64), array([673], dtype=int64), array([681], dtype=int64), array([689], dtype=int64), array([697], dtype=int64), array([705], dtype=int64), array([713], dtype=int64), array([721], dtype=int64)]
#     File Indices:  [547 553 559 565 571 577 583 589 595 601 607 613 619 625 633 641 649 657
#  665 673 681 689 697 705 713 721]
#     Getting trace...
# 100%|██████████| 26/26 [07:08<00:00, 16.47s/it]
# Cell Indices:  [  0   0   0 519 444 337   0  22 242   0 313 216 198 217 111 116  90  49
#  181  42 212 124 173 144 207 121]
#    0/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0   0 146 558 661 623 483 480 468 449 434 496 475 437 393
#  538 490 523 494 393 385 274 414]
#    1/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0   0 194 307  40 210 130 295 363 281 257 218 208 212 338
#  402 393 490 414 489 407 332 348]
#    2/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0   0 253 515 264 257 147 339 273 188 254 430 308 327 414
#  510 388 533 496 506 395 290 374]
#    3/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0   0 406 433 173 412 185 312 197 163 119 320 205 326 167
#  357 157 394 134 197 102 132 300]
#    4/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0 509   0   0 494 567 678 467 407 372 293 342 346 251 223  95
#  257 169 391 188 150 153  51  51]
#    5/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0  39 101 183 171 137  94 403 303 110 276 279   0   0 112  42  39   0
#  253  36 353 249 254 168   0 316]
#    6/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0 380 398 372 109 432 418 585 385 372 269 258 135 142  72 152 148   0
#  332   0 211 146   0 201   0 241]
#    7/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0   0 540 573 390 442 365 460 429 303 431 429 438 378 360
#  550 485 553 473 546 480 506 448]
#    8/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [ 87   0 233 294 189 306 286  61 226 114 353 246 260   0 168 287 185   0
#  541 186   0 207 264 188   0 237]
#    9/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0  78 165 168  72  87 437   0 426 247 245 298   0 424 348   0 365
#  155 208  17  39  21  54 114 123]
#    10/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0 358   0 274  92 214 121 283 261 254 128 290 311 284 238
#  370 283 384 296 276 203 234 249]
#    11/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0   0 508 540 279 403 456 474 455 452 449 471 503 379 401
#  535 400 555 515 516 471 562 494]
#    12/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0   0 414 334 108 357 402 369 306 150 105 334 353 250 296
#  445 264 519 457 358 423 467 379]
#    13/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0 423 297 282 168 260 446 253 303 250 396   0   0   0 354 315 298
#  226 406 225 383 217 223 143 156]
#    14/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0 507 239 398 291 299 615 489 476 321 409 396 427   0 434 429 413
#  383   0  92 431 357 365 338   0]
#    15/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0   0 111 296 401 203 355 459 423 356 371 363 255 241 325
#  151 237 365 243  68 157  70 143]
#    16/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0 112   0   0 267 195 410  36  20   5  57  59  23 180  98  60 100
#   86  82 222   0 159 316 309 232]
#    17/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0   0   0 512 559 510 552 432 380 271 279 338 271 143 290 233
#   18 229 249 301 185 334 367 398]
#    18/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0  61 167 210 144 489   0 393 465   0 402 390 257 305   0 192 306 234
#  384 303 304 350 424   0 366 272]
#    19/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [  0   0   0 499   0 560 392 514 162 141   0 100  50  63 195 142  74  86
#   80  56 180 180 193  80 211 288]
#    20/22, cell num = 21
#     Plot over, saving figure...
# Cell Indices:  [299   0   0   0 371   0   0 429 152  96 394 253 364 367 397 351 358 352
#  455 381 496 326 448 419 399 463]
#    21/22, cell num = 21
#     Plot over, saving figure...
# 20 [ 86  99 100 105 106 108 111 113 114 115 116 126 142 145 146 147 149 150
#  151 166 168 196 197 201 203 206 214 215 218 219 229 235 238 250 256 288
#  330]
#         D:\Data\FinalResults\Field Analysis\0310 - Test MultiDayModel\10232-HMP\20 Cells is made up successfully!
# [array([547], dtype=int64), array([553], dtype=int64), array([559], dtype=int64), array([565], dtype=int64), array([571], dtype=int64), array([577], dtype=int64), array([583], dtype=int64), array([589], dtype=int64), array([595], dtype=int64), array([601], dtype=int64), array([607], dtype=int64), array([613], dtype=int64), array([619], dtype=int64), array([625], dtype=int64), array([633], dtype=int64), array([641], dtype=int64), array([649], dtype=int64), array([657], dtype=int64), array([665], dtype=int64), array([673], dtype=int64), array([681], dtype=int64), array([689], dtype=int64), array([697], dtype=int64), array([705], dtype=int64), array([713], dtype=int64), array([721], dtype=int64)]
#     File Indices:  [547 553 559 565 571 577 583 589 595 601 607 613 619 625 633 641 649 657
#  665 673 681 689 697 705 713 721]
#     Getting trace...
#  69%|██████▉   | 18/26 [05:44<02:26, 18.33s/it]
