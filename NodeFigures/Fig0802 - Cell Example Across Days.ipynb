# %%
from mylib.statistic_test import *

code_id = '0802 - Cell Example Across Days'
loc = os.path.join(figpath, 'Dsp', code_id)
mkdir(loc)

# Mouse 10224
mouse = 10224
index_map = ReadCellReg(f_CellReg_dsp['cellreg_folder'][np.where(f_CellReg_dsp['MiceID'] == mouse)[0][0]]).astype(np.int64)
cell_num = np.nansum(np.where(index_map!=0, 1, 0), axis=0)
idx = np.argsort(cell_num)[::-1]

index_map = index_map[:, idx]

file_indices = np.where(f2['MiceID'] == mouse)[0]
traces = []
for i in file_indices:
    print(f2['Trace File'][i])
    with open(f2['Trace File'][i], 'rb') as handle:
        trace = pickle.load(handle)
    traces.append(trace)
# Out:
#         E:\Data\FinalResults\Dsp\0802 - Cell Example Across Days is already existed!
# E:\Data\Dsp_maze\10224\20231009\trace.pkl
# E:\Data\Dsp_maze\10224\20231010\trace.pkl
# E:\Data\Dsp_maze\10224\20231011\trace.pkl
# E:\Data\Dsp_maze\10224\20231012\trace.pkl
# E:\Data\Dsp_maze\10224\20231013\trace.pkl
# E:\Data\Dsp_maze\10224\20231014\trace.pkl
# E:\Data\Dsp_maze\10224\20231015\trace.pkl

# %%
def plot_cell_examples_across_days(index_map, traces, save_loc):
    assert len(traces) == index_map.shape[0]
    
    adds = np.linspace(0, 600, 7)
    last_time = np.array([trace['correct_time'][-1] for trace in traces])
    last_time = np.concatenate([[0], last_time[:-1]])
    tot_additions = adds + np.cumsum(last_time)
    
    colors = [
        DSPPalette[0], DSPPalette[1], DSPPalette[2], DSPPalette[3], DSPPalette[0],
        DSPPalette[0], DSPPalette[4], DSPPalette[5], DSPPalette[6], DSPPalette[0]
    ]
    
    fig = plt.figure(figsize=(4, 4*7))
    ax = Clear_Axes(plt.axes(), close_spines=['top', 'right'], ifxticks=True, ifyticks=True)
    for cell in np.arange(index_map.shape[1]):
        print(f"Plotting Cell {index_map[:, cell]} at column {cell}...")
        y_ticks = []
        y_labels = []
        for d, trace in enumerate(traces):
            if index_map[d, cell] == 0:
                continue
        
            for i in range(10):
                ax = LocTimeCurveAxes(
                    ax,
                    behav_time=trace[f'node {i}']['ms_time_behav'] + tot_additions[d],
                    behav_nodes=spike_nodes_transform(trace[f'node {i}']['spike_nodes'], 12),
                    spikes=trace[f'node {i}']['Spikes'][index_map[d, cell]-1, :],
                    spike_time=trace[f'node {i}']['ms_time_behav'] + tot_additions[d],
                    maze_type=1,
                    line_kwargs={'linewidth': 0.4, 'color': colors[i]},
                    bar_kwargs={'markeredgewidth': 0.5, 'markersize': 2, 'color': 'k'},
                    is_include_incorrect_paths=True
                )[0]
            
            t1 = trace['node 4']['ms_time_behav'][-1]/1000 + tot_additions[d]/1000
            t2 = trace['node 5']['ms_time_behav'][0]/1000 + tot_additions[d]/1000
            t3 = trace['node 9']['ms_time_behav'][-1]/1000 + tot_additions[d]/1000
            y_ticks += [0, t1, t2, t3]
            y_labels += [0, t1, 0, t3-t2]
        
        ax.set_yticks(y_ticks, y_labels)
        plt.savefig(os.path.join(save_loc, f'cell_{cell+1}.png'), dpi=600)
        plt.savefig(os.path.join(save_loc, f'cell_{cell+1}.svg'), dpi=600)
        ax.clear()
            
save_loc = os.path.join(loc, f"{mouse}")
mkdir(save_loc)
plot_cell_examples_across_days(index_map, traces, save_loc)
# Out:
#         E:\Data\FinalResults\Dsp\0802 - Cell Example Across Days\10224 is already existed!
# Plotting Cell [  1   1   1   1   1 100   4] at column 0...
# Plotting Cell [181  47  29  24  87 106 107] at column 1...
# Plotting Cell [184 137 101 102  53  43  74] at column 2...
# Plotting Cell [185 151  33  43  10  68 179] at column 3...
# Plotting Cell [190 247 234 212 161 273 224] at column 4...
# Plotting Cell [201 114 137 195 133 278 198] at column 5...
# Plotting Cell [467 401 355 390 323 353 369] at column 6...
# Plotting Cell [206 171 248 154 207 232 246] at column 7...
# Plotting Cell [463 407 392 398 391 404 358] at column 8...
# Plotting Cell [209 163  44 103 110 196 282] at column 9...
# Plotting Cell [458 295  59 216 390 164 283] at column 10...
# Plotting Cell [457 215  87 417  46 359 259] at column 11...
# Plotting Cell [212 257 212 159 150 200 171] at column 12...
# Plotting Cell [454 359 317 400 387 319 351] at column 13...
# Plotting Cell [449 367 319 321 319 381 337] at column 14...
# Plotting Cell [441 399 371 351 271 360 350] at column 15...
# Plotting Cell [222 239 161 193 214 133 109] at column 16...
# Plotting Cell [223 110  96  75  13   3  20] at column 17...
# Plotting Cell [430 388 380 397 372 316 360] at column 18...
# Plotting Cell [421 373 308 386 339 382 374] at column 19...
# Plotting Cell [235 169 214  55 122  75  34] at column 20...
# Plotting Cell [182  95  74 119 297  45 288] at column 21...
# Plotting Cell [171 149  53 187 279 212 261] at column 22...
# Plotting Cell [239 167 258 332 246 221 416] at column 23...
# Plotting Cell [167 310 177 285  35  94 253] at column 24...
# Plotting Cell [376 156 282 263 208 378 196] at column 25...
# Plotting Cell [107  20  50 203  48 174 135] at column 26...
# Plotting Cell [108 183 150  17 341 121  30] at column 27...
# Plotting Cell [120  89  19 284  16 218  55] at column 28...
# Plotting Cell [123  67  35   8  73   7  12] at column 29...
# Plotting Cell [127  64  72 131 134 101  97] at column 30...
# Plotting Cell [130 121 324 142  29 111 142] at column 31...
# Plotting Cell [131 173  75  84 127 210 187] at column 32...
# Plotting Cell [256 390 303 316 182 186 217] at column 33...
# Plotting Cell [132 191 259  89  17 193  15] at column 34...
# Plotting Cell [137 176 227 289 260  96 209] at column 35...
# Plotting Cell [204 164  86 213  54 234  47] at column 36...
# Plotting Cell [139  63 202 182 121 110 211] at column 37...
# Plotting Cell [141  83  38  77  98 165 189] at column 38...
# Plotting Cell [144 113 108   6  66 145  52] at column 39...
# Plotting Cell [148  99   2  16 111  79  51] at column 40...
# Plotting Cell [154 323 138 115 229 301 230] at column 41...
# Plotting Cell [162 237 271 274 253  18 247] at column 42...
# Plotting Cell [165 152 112 126 151 176 252] at column 43...
# Plotting Cell [408 414 369 272 376 375 381] at column 44...
# Plotting Cell [243 230 330 380 375 398 415] at column 45...
# Plotting Cell [101 107 127 188  49 389  84] at column 46...
# Plotting Cell [260 205 196 179 129 107  40] at column 47...
# Plotting Cell [264 254 270 218  82 226 231] at column 48...
# Plotting Cell [336 197 169 375 340 411 419] at column 49...
# Plotting Cell [333 332 394 381 394 417 366] at column 50...
# Plotting Cell [332 265 217 295 349 305 267] at column 51...
# Plotting Cell [328 322 159 231 251 187 308] at column 52...
# Plotting Cell [327 218 186 394 264 416 390] at column 53...
# Plotting Cell [324 105 100  93  94 130 152] at column 54...
# Plotting Cell [322 306 256 329 335 306 391] at column 55...
# Plotting Cell [315 252 132 137  15 161   9] at column 56...
# Plotting Cell [312 242 331 288 310 294 364] at column 57...
# Plotting Cell [308 291 195 309 136 171  88] at column 58...
# Plotting Cell [306 141 126 118  42 390  18] at column 59...
# Plotting Cell [302 255 197  81  38  31 123] at column 60...
# Plotting Cell [296 261 255 169 124  77 169] at column 61...
# Plotting Cell [295 189 134 164 187 219 362] at column 62...
# Plotting Cell [293 153 315 165 274  51 115] at column 63...
# Plotting Cell [289 221 145 129 345 350 317] at column 64...
# Plotting Cell [286 253 199 147 244 227 306] at column 65...
# Plotting Cell [283 227 106 260 146  44 114] at column 66...
# Plotting Cell [263 226 252 120 180 208  98] at column 67...
# Plotting Cell [258 307 373 313 317 344 333] at column 68...
# Plotting Cell [398 369 296 308 217 163 163] at column 69...
# Plotting Cell [357 304 175 134 291 209 251] at column 70...
# Plotting Cell [244 381 314 176  96  90  27] at column 71...
# Plotting Cell [396 222 182 177 306 405 378] at column 72...
# Plotting Cell [395 374 312 314 332 340 228] at column 73...
# Plotting Cell [394 344 269 292 281 272 278] at column 74...
# Plotting Cell [391 290 181 244 240 361 299] at column 75...
# Plotting Cell [388 348 348 368 329 351 372] at column 76...
# Plotting Cell [247  30 354  48 115 406 399] at column 77...
# Plotting Cell [384 349   6  57  58  81   7] at column 78...
# Plotting Cell [383 341 242 223 159 345 235] at column 79...
# Plotting Cell [248 263 211 122 327 386 365] at column 80...
# Plotting Cell [380 283 310 270 312 330 298] at column 81...
# Plotting Cell [379 104 280 391 235 231 264] at column 82...
# Plotting Cell [249 122  83 210 143 157 170] at column 83...
# Plotting Cell [373 398 391 369 367 391 332] at column 84...
# Plotting Cell [371 384 328 225 191 249 244] at column 85...
# Plotting Cell [367 347 293 388 287 170 273] at column 86...
# Plotting Cell [365 319 297 302 237 224 377] at column 87...
# Plotting Cell [254 214 165 109 231 252 322] at column 88...
# Plotting Cell [359 203 249 407 289  15 302] at column 89...
# Plotting Cell [104 287 229 290 285 141 289] at column 90...
# Plotting Cell [278 262 386 354 370  99 138] at column 91...
# Plotting Cell [ 11  26  34 171  12 237  31] at column 92...
# Plotting Cell [55 65 36 30 18 46 70] at column 93...
# Plotting Cell [ 43  28  31  21  75 166 104] at column 94...
# Plotting Cell [ 60 232 209 170 202  42 225] at column 95...
# Plotting Cell [ 9 48  7 82 62 92 82] at column 96...
# Plotting Cell [ 90  81 109 191 132 238 234] at column 97...
# Plotting Cell [ 15  80 222 149 266  47 347] at column 98...
# Plotting Cell [ 58 224 118 108 157 201 263] at column 99...
# Plotting Cell [83 51 39 50 21 21 32] at column 100...
# Plotting Cell [ 88  39 120 202  68  26 125] at column 101...
# Plotting Cell [ 10  21  25  98 104  72 238] at column 102...
# Plotting Cell [ 22  66  90  58  34 177  63] at column 103...
# Plotting Cell [ 80  98 187 297 170 327 151] at column 104...
# Plotting Cell [ 41  70 240  47 112  80  43] at column 105...
# Plotting Cell [ 82 150   5 123  24  57  42] at column 106...
# Plotting Cell [48 54 76 96 19 52 60] at column 107...
# Plotting Cell [ 39  41 115  61  95 138 132] at column 108...
# Plotting Cell [ 75 202 287 206 176 324 373] at column 109...
# Plotting Cell [ 66 126  16 145 113  13  68] at column 110...
# Plotting Cell [  3  40  22  97   9 197 159] at column 111...
# Plotting Cell [ 52  29 221  45 118 143 243] at column 112...
# Plotting Cell [ 54  84 110 135 204  41 140] at column 113...
# Plotting Cell [ 36  85  91  67 205 244 188] at column 114...
# Plotting Cell [ 12  12   8 242 107 304 156] at column 115...
# Plotting Cell [ 91  27  64  32  32 230 131] at column 116...
# Plotting Cell [ 95 103  47  56   6   5   3] at column 117...
# Plotting Cell [ 49  44 263  22 109 135 137] at column 118...
# Plotting Cell [ 23   3  30 183 123 308 141] at column 119...
# Plotting Cell [251  52   0 189 171 154  65] at column 120...
# Plotting Cell [ 32 273  40  20  83 173   0] at column 121...
# Plotting Cell [253 210 299 384 365 396   0] at column 122...
# Plotting Cell [ 33   0 117  63  28  85  77] at column 123...
# Plotting Cell [199 236 163 197   0 134 199] at column 124...
# Plotting Cell [374 324 153 153 181 172   0] at column 125...
# Plotting Cell [ 71   0 162 350 142 364 236] at column 126...
# Plotting Cell [191  68 190   0  81  10   6] at column 127...
# Plotting Cell [197   0 276 141 212  22 318] at column 128...
# Plotting Cell [196   0 253 357 344 254 270] at column 129...
# Plotting Cell [347 337   0 286 366 116 287] at column 130...
# Plotting Cell [176 234 336   0 162 312 193] at column 131...
# Plotting Cell [259 211 305 144 255   0 214] at column 132...
# Plotting Cell [ 28 134 341 269 346   0 303] at column 133...
# Plotting Cell [267 216 180   0 200 109 108] at column 134...
# Plotting Cell [352   0 286 294 186 120 208] at column 135...
# Plotting Cell [183 178 124 162 141  66   0] at column 136...
# Plotting Cell [356 325 246 303 300 263   0] at column 137...
# Plotting Cell [ 29 199  14 346 389   0 380] at column 138...
# Plotting Cell [358 235 329 230 384  24   0] at column 139...
# Plotting Cell [30  9  3  5  5  2  0] at column 140...
# Plotting Cell [361 125  89   0 256 127 116] at column 141...
# Plotting Cell [189   0 191 139  56  98 101] at column 142...
# Plotting Cell [ 73  45  95 291   0 195 207] at column 143...
# Plotting Cell [459 391 374 382 351   0 388] at column 144...
# Plotting Cell [192 170   0  64  52 240  62] at column 145...
# Plotting Cell [195  88  15   0 154 142  14] at column 146...
# Plotting Cell [ 68 117 119 226 267   0 290] at column 147...
# Plotting Cell [440 393 251 344   0 387 314] at column 148...
# Plotting Cell [375 351   0 337 299 370 324] at column 149...
# Plotting Cell [ 64 102 140   0 201  35 124] at column 150...
# Plotting Cell [425 346 375 378 311   0 410] at column 151...
# Plotting Cell [424 394 316   0 295 385 389] at column 152...
# Plotting Cell [423 352 339 184 206 276   0] at column 153...
# Plotting Cell [ 56   0 166  80 158 245 102] at column 154...
# Plotting Cell [393   0 281 249 164 323 183] at column 155...
# Plotting Cell [47 24  9 44 74  0 89] at column 156...
# Plotting Cell [236 250   0 298 272 310 239] at column 157...
# Plotting Cell [237  76   0 217 277 262 191] at column 158...
# Plotting Cell [238 145  61 266  59   0  57] at column 159...
# Plotting Cell [50 37 78  0 40 55 75] at column 160...
# Plotting Cell [51 43 71 95  0 38 80] at column 161...
# Plotting Cell [410 370 267 221 280   0 293] at column 162...
# Plotting Cell [399 186  46 366 334 182   0] at column 163...
# Plotting Cell [401 321 400 372 392   0 414] at column 164...
# Plotting Cell [402   0 301 376 337 328 359] at column 165...
# Plotting Cell [229 275 125   0 227 220  61] at column 166...
# Plotting Cell [228 278   0 163 144  89 168] at column 167...
# Plotting Cell [225   0  69  42 169  93 144] at column 168...
# Plotting Cell [220 166 278 239 195 346   0] at column 169...
# Plotting Cell [213 142  65   0 286 206 272] at column 170...
# Plotting Cell [216 188 200 211   0 269 220] at column 171...
# Plotting Cell [ 63  96  51  85 145   0 197] at column 172...
# Plotting Cell [325 313 351 373 343 259   0] at column 173...
# Plotting Cell [219 208   0 237 252 175 280] at column 174...
# Plotting Cell [445 385 192 323 233   0 301] at column 175...
# Plotting Cell [443 378 390   0 352 129  11] at column 176...
# Plotting Cell [389 148 233 306 172 358   0] at column 177...
# Plotting Cell [ 42 182   0 267 223 338 277] at column 178...
# Plotting Cell [439 380 412 359 330 394   0] at column 179...
# Plotting Cell [438   0 357 343 322 132 339] at column 180...
# Plotting Cell [ 61  36 142 100  60   0 105] at column 181...
# Plotting Cell [433 172 372 404   0 363 182] at column 182...
# Plotting Cell [ 45 140  57  14 155 192   0] at column 183...
# Plotting Cell [344 353 333   0 403 393 383] at column 184...
# Plotting Cell [  0 274 223 282 315 325 285] at column 185...
# Plotting Cell [271 217 307 392 198 341   0] at column 186...
# Plotting Cell [  0  50 376 233 284 255 330] at column 187...
# Plotting Cell [124  71   0 229 316 216 153] at column 188...
# Plotting Cell [125 220 152   0 224  69  33] at column 189...
# Plotting Cell [128  91  84 101  88  48   0] at column 190...
# Plotting Cell [129 159  49 167   4  29   0] at column 191...
# Plotting Cell [305 109 257 124 301 290   0] at column 192...
# Plotting Cell [307   0 143 156  14   8  23] at column 193...
# Plotting Cell [  0 281 353 261 147 217 204] at column 194...
# Plotting Cell [273 276   0 333 196 379 315] at column 195...
# Plotting Cell [  0  93 208  49 105  27  66] at column 196...
# Plotting Cell [310 190 206  92  67   0 157] at column 197...
# Plotting Cell [272 318 185 273 219 282   0] at column 198...
# Plotting Cell [313 267 318   0 203 205 232] at column 199...
# Plotting Cell [ 86 292 220 241 263   0 180] at column 200...
# Plotting Cell [ 85 115  88 110  69   0 192] at column 201...
# Plotting Cell [138 282   0  23 102 167  83] at column 202...
# Plotting Cell [ 92 143   0 125 148  32  58] at column 203...
# Plotting Cell [274 271 184 172  70   0 201] at column 204...
# Plotting Cell [269   0  92  59 194  84  94] at column 205...
# Plotting Cell [299 326 361 204 139 229   0] at column 206...
# Plotting Cell [ 98 123 102 271 276   0 409] at column 207...
# Plotting Cell [277 213 207 240 290   0 117] at column 208...
# Plotting Cell [284 299 160 389   0 412 205] at column 209...
# Plotting Cell [105 106   0  88  45  37 113] at column 210...
# Plotting Cell [  0 200 346 315 250 307 354] at column 211...
# Plotting Cell [ 40 223   0 262 178 199  99] at column 212...
# Plotting Cell [ 96 181 139  37  61   0  26] at column 213...
# Plotting Cell [276 154 387 219 185   0 300] at column 214...
# Plotting Cell [287 129   0 121 114 214 150] at column 215...
# Plotting Cell [  0  42 123  60  50  20  22] at column 216...
# Plotting Cell [110  74  85  65 245   0 200] at column 217...
# Plotting Cell [  6   6  73 132 108   0  67] at column 218...
# Plotting Cell [  7   0 213 114  92 113 155] at column 219...
# Plotting Cell [116  49   0  53  47  17  71] at column 220...
# Plotting Cell [119   0 415 328 268 261 184] at column 221...
# Plotting Cell [ 14   0  97 117 120 125 154] at column 222...
# Plotting Cell [242 246 135   0 296  14  54] at column 223...
# Plotting Cell [164 168  58  71  99   0 110] at column 224...
# Plotting Cell [330 297   0 228 305 235 307] at column 225...
# Plotting Cell [ 20  33  17   0 179  40 223] at column 226...
# Plotting Cell [ 19  78 113 105   0 131 118] at column 227...
# Plotting Cell [  0 144 133 196 137  54  44] at column 228...
# Plotting Cell [157  62  43  31   0  86  78] at column 229...
# Plotting Cell [  0 419  62  69 270 122 127] at column 230...
# Plotting Cell [166  16  27  83 140   0 122] at column 231...
# Plotting Cell [323 180 168 194   0 264 146] at column 232...
# Plotting Cell [ 81  86  93 158 265 184   0] at column 233...
# Plotting Cell [143   0 291  62  41  58 260] at column 234...
# Plotting Cell [321 289 201   0 234 149 134] at column 235...
# Plotting Cell [320   0 358 318 197 347 356] at column 236...
# Plotting Cell [170   0 232  70 308 233 316] at column 237...
# Plotting Cell [160 175 178   0 303 288 323] at column 238...
# Plotting Cell [334 132 289 258 364 253   0] at column 239...
# Plotting Cell [ 8 23 13 11 64  0  0] at column 240...
# Plotting Cell [257 116 158 112   0  63   0] at column 241...
# Plotting Cell [292   0 332   0 273 367 335] at column 242...
# Plotting Cell [245   0 306  86  76   0 320] at column 243...
# Plotting Cell [46 11 18 28  0  0 39] at column 244...
# Plotting Cell [294   0 295 335   0 228 215] at column 245...
# Plotting Cell [265   0 262 220   0  60  50] at column 246...
# Plotting Cell [369 397 236 420 363   0   0] at column 247...
# Plotting Cell [290 161 423 281 167   0   0] at column 248...
# Plotting Cell [291 204 114   0 382 265   0] at column 249...
# Plotting Cell [353   0   0 339  77 318 256] at column 250...
# Plotting Cell [298  75   0 173 398 283   0] at column 251...
# Plotting Cell [337   0   0 247 257 194 181] at column 252...
# Plotting Cell [  5   7   0 151   0  87  21] at column 253...
# Plotting Cell [351 362   0 215 377 147   0] at column 254...
# Plotting Cell [338 196 284 252   0 376   0] at column 255...
# Plotting Cell [25 22  0  0 11 56 19] at column 256...
# Plotting Cell [261 174   0 374   0 331 344] at column 257...
# Plotting Cell [ 26 308  26   0 395 339   0] at column 258...
# Plotting Cell [403 327 370 342 359   0   0] at column 259...
# Plotting Cell [346   0 111   0   8  70  64] at column 260...
# Plotting Cell [297   0   0 334 402 415 404] at column 261...
# Plotting Cell [360 259 238 361 318   0   0] at column 262...
# Plotting Cell [255 160 198   0 243   0 342] at column 263...
# Plotting Cell [301 285 193 287   0   0 265] at column 264...
# Plotting Cell [ 35  60 136  90   0 136   0] at column 265...
# Plotting Cell [268 317 149   0   0 333 249] at column 266...
# Plotting Cell [319   0   0 365 225 321 262] at column 267...
# Plotting Cell [270   0 334 401 412   0 408] at column 268...
# Plotting Cell [364 330 277 336   0 298   0] at column 269...
# Plotting Cell [250 339 144 275   0   0 221] at column 270...
# Plotting Cell [377   0 203 235   0 168  72] at column 271...
# Plotting Cell [345   0 170 238   0 409 413] at column 272...
# Plotting Cell [ 37   4   0   0 209  73  25] at column 273...
# Plotting Cell [ 31 248 210   0   0 204 294] at column 274...
# Plotting Cell [16  5 23 18  0  0 93] at column 275...
# Plotting Cell [382 184 216 257   0 243   0] at column 276...
# Plotting Cell [362   0   0 265 325 284 258] at column 277...
# Plotting Cell [304 238   0   0 160 151  90] at column 278...
# Plotting Cell [329 294 347   0 368   4   0] at column 279...
# Plotting Cell [ 44 111  63 349   0   0 297] at column 280...
# Plotting Cell [  0 198 237 379 228   0 149] at column 281...
# Plotting Cell [386 241 226 207 153   0   0] at column 282...
# Plotting Cell [387 303 326   0 380   0 417] at column 283...
# Plotting Cell [370 138 130 174   0 309   0] at column 284...
# Plotting Cell [21  0 42 12 27 36  0] at column 285...
# Plotting Cell [343   0 151 268   0 274 254] at column 286...
# Plotting Cell [ 99 279   0  29 215   0  17] at column 287...
# Plotting Cell [405 219 311 250   0 348   0] at column 288...
# Plotting Cell [  0   0  80 175 210 150  92] at column 289...
# Plotting Cell [  0   0  37  46  23 112  24] at column 290...
# Plotting Cell [  0 100 155   0  55 285  73] at column 291...
# Plotting Cell [140   0   0 146 189  62 136] at column 292...
# Plotting Cell [ 0  0 67 26 44 28 56] at column 293...
# Plotting Cell [142 192 279 104   0   0 167] at column 294...
# Plotting Cell [145  72  66   0  86   0  79] at column 295...
# Plotting Cell [146   0   0 293 232 292 213] at column 296...
# Plotting Cell [  0 418   0 360 275 337 268] at column 297...
# Plotting Cell [149 233   0 214  89   0  29] at column 298...
# Plotting Cell [150 185 235 201 190   0   0] at column 299...
# Plotting Cell [151 177   0 106 131 225   0] at column 300...
# Plotting Cell [158 311   0  38 213  49   0] at column 301...
# Plotting Cell [159 350 243 277 357   0   0] at column 302...
# Plotting Cell [161   0  48 199 193 203   0] at column 303...
# Plotting Cell [163 135 230 208 192   0   0] at column 304...
# Plotting Cell [  0 376 368   0 379 372 396] at column 305...
# Plotting Cell [397 368 309 312   0 257   0] at column 306...
# Plotting Cell [ 79 101 116   0   0  74 195] at column 307...
# Plotting Cell [ 78 187 107  41   0 159   0] at column 308...
# Plotting Cell [168   0 231   0 358 373 328] at column 309...
# Plotting Cell [  0 320 290 317 314   0 206] at column 310...
# Plotting Cell [ 77  61  20  68   0   0 226] at column 311...
# Plotting Cell [173   0   0  72 116 114  28] at column 312...
# Plotting Cell [  0  57  68  40  51 180   0] at column 313...
# Plotting Cell [  0 112 104 307   0 155 312] at column 314...
# Plotting Cell [  0 266 350   0 242 148 203] at column 315...
# Plotting Cell [136   0  45   0  80 256  96] at column 316...
# Plotting Cell [102  73 156 116   0   0 281] at column 317...
# Plotting Cell [103 118 105   0   0  82 120] at column 318...
# Plotting Cell [ 97   0 141 160 168  64   0] at column 319...
# Plotting Cell [106   0  56  19   0 118 129] at column 320...
# Plotting Cell [  0   0  12 136  30 179 212] at column 321...
# Plotting Cell [94 19  0 35 20  0 85] at column 322...
# Plotting Cell [109   0  54   0  37  53  46] at column 323...
# Plotting Cell [112 124   0 243   0 267 340] at column 324...
# Plotting Cell [113 128 167 301   0  88   0] at column 325...
# Plotting Cell [115   0 174 130 239 334   0] at column 326...
# Plotting Cell [117 225  28   0 103 287   0] at column 327...
# Plotting Cell [  0   0 408 418 399 383 406] at column 328...
# Plotting Cell [118   0  52  34   0 104  86] at column 329...
# Plotting Cell [447 403 395 403   0   0 370] at column 330...
# Plotting Cell [126 162   0 299 362   0 271] at column 331...
# Plotting Cell [  0   0 325 353 313 349 250] at column 332...
# Plotting Cell [ 89   0 129 200 101  95   0] at column 333...
# Plotting Cell [  0 298 272 385 292   0 145] at column 334...
# Plotting Cell [  0 207 275 283 130  19   0] at column 335...
# Plotting Cell [134 244 122 143   0   0 295] at column 336...
# Plotting Cell [  0   0 189  54  72   9  87] at column 337...
# Plotting Cell [  0 212 183 138   0 289 355] at column 338...
# Plotting Cell [135  56 172   0  90 311   0] at column 339...
# Plotting Cell [174 130 131   0   0 211 165] at column 340...
# Plotting Cell [169  94   0   0 236 117 321] at column 341...
# Plotting Cell [178 240 103   0  39   0 112] at column 342...
# Plotting Cell [205 309 264 140   0 354   0] at column 343...
# Plotting Cell [465 365 363 406   0   0 401] at column 344...
# Plotting Cell [207   0 352 319   0 124 119] at column 345...
# Plotting Cell [ 69   8  21   0 293   6   0] at column 346...
# Plotting Cell [208   2   0 251   0  76  59] at column 347...
# Plotting Cell [461 340 250 264   0 300   0] at column 348...
# Plotting Cell [ 67 258 320  78   0 369   0] at column 349...
# Plotting Cell [451 405 384 423 407   0   0] at column 350...
# Plotting Cell [217   0 121   3  25  30   0] at column 351...
# Plotting Cell [218 277 188 192   0 277   0] at column 352...
# Plotting Cell [100  17   0  15 125  23   0] at column 353...
# Plotting Cell [437 356 377 399   0 422   0] at column 354...
# Plotting Cell [436 415 381   0 374   0 375] at column 355...
# Plotting Cell [431   0   0 161 331  16 286] at column 356...
# Plotting Cell [230   0   0 222 388 139 111] at column 357...
# Plotting Cell [231 108 413   0 336 270   0] at column 358...
# Plotting Cell [234 280   0 198   0  91 166] at column 359...
# Plotting Cell [413 312   0 279   0 329 325] at column 360...
# Plotting Cell [412   0 283 280 259   0 158] at column 361...
# Plotting Cell [411   0   0 377 184 313 178] at column 362...
# Plotting Cell [409   0   0 348 218 357 371] at column 363...
# Plotting Cell [ 53  59   0 168   0 115 103] at column 364...
# Plotting Cell [ 70  53  98  27   0   0 160] at column 365...
# Plotting Cell [210   0 147   0 248 223 194] at column 366...
# Plotting Cell [186 201 385   0  57 146   0] at column 367...
# Plotting Cell [ 76  14 228   0 238 399   0] at column 368...
# Plotting Cell [ 74  69  60   0 149   0 361] at column 369...
# Plotting Cell [  0 264 393 227 307 343   0] at column 370...
# Plotting Cell [279 286   0   0 211 207 237] at column 371...
# Plotting Cell [  0  79   0 340  78 169  76] at column 372...
# Plotting Cell [188  92  10   0   0  25  16] at column 373...
# Plotting Cell [  0 131 335  99  22   0 100] at column 374...
# Plotting Cell [ 0 10 77  4  0  1 45] at column 375...
# Plotting Cell [193 146 300   0  85   0 229] at column 376...
# Plotting Cell [179   0 204 107   0 108   8] at column 377...
# Plotting Cell [198 209 356   0   0  67 177] at column 378...
# Plotting Cell [ 72  38 302   0  26   0 175] at column 379...
# Plotting Cell [  0 158 215  76   0  71 174] at column 380...
# Plotting Cell [  4   0   0   7   0 190   1] at column 381...
# Plotting Cell [241 272 294   0   0 352   0] at column 382...
# Plotting Cell [275   0   0 190 241   0 106] at column 383...
# Plotting Cell [180   0 219 276 258   0   0] at column 384...
# Plotting Cell [262   0 274 255   0 181   0] at column 385...
# Plotting Cell [233   0 241 383   0 281   0] at column 386...
# Plotting Cell [111  77  24  74   0   0   0] at column 387...
# Plotting Cell [232   0   0 186 262   0  91] at column 388...
# Plotting Cell [114  58   0  79   0   0 173] at column 389...
# Plotting Cell [ 24  13   0 181 156   0   0] at column 390...
# Plotting Cell [246   0   0 224 294   0 202] at column 391...
# Plotting Cell [252   0   0 180 324   0 305] at column 392...
# Plotting Cell [224   0   0 370 261 260   0] at column 393...
# Plotting Cell [ 93 157 205   0   0 302   0] at column 394...
# Plotting Cell [203 314 254   0 354   0   0] at column 395...
# Plotting Cell [122   0   0 341   0 413 393] at column 396...
# Plotting Cell [187 206   0 236   0   0  69] at column 397...
# Plotting Cell [ 62   0   0   0 309  12   2] at column 398...
# Plotting Cell [221  55   0   0 254   0   5] at column 399...
# Plotting Cell [133 194  70   0   0   0 233] at column 400...
# Plotting Cell [ 38  32   0 150 135   0   0] at column 401...
# Plotting Cell [215   0   0  91   0 160  36] at column 402...
# Plotting Cell [ 65   0  41 111 100   0   0] at column 403...
# Plotting Cell [175 127   0   0 119 137   0] at column 404...
# Plotting Cell [266   0 154   0 175   0 147] at column 405...
# Plotting Cell [152 231   0   0  43 248   0] at column 406...
# Plotting Cell [202  90 148   0  93   0   0] at column 407...
# Plotting Cell [121 251   0   0  63 320   0] at column 408...
# Plotting Cell [348   0 171 256 269   0   0] at column 409...
# Plotting Cell [280   0 268   0   0 297 352] at column 410...
# Plotting Cell [  0   0 406   0 371 371 329] at column 411...
# Plotting Cell [  0 329  79 327   0   0 341] at column 412...
# Plotting Cell [  0 268 321   0 283   0 130] at column 413...
# Plotting Cell [  0 136   0  94   0 103 219] at column 414...
# Plotting Cell [  0 147 266   0   0  78 255] at column 415...
# Plotting Cell [  0 119   0   0 106  34  37] at column 416...
# Plotting Cell [  0  35   0   0 165  97 284] at column 417...
# Plotting Cell [ 0 18  0 10  2  0 10] at column 418...
# Plotting Cell [479 423 420   0 409   0   0] at column 419...
# Plotting Cell [469 410   0 429 411   0   0] at column 420...
# Plotting Cell [416   0 365   0 381   0 411] at column 421...
# Plotting Cell [456 357   0 311   0  39   0] at column 422...
# Plotting Cell [455   0   0   0 355 377 313] at column 423...
# Plotting Cell [448   0   0 387   0 414 403] at column 424...
# Plotting Cell [444 375 265   0 278   0   0] at column 425...
# Plotting Cell [434   0   0 325 221   0 257] at column 426...
# Plotting Cell [432 333   0 419 350   0   0] at column 427...
# Plotting Cell [426 354 411   0 396   0   0] at column 428...
# Plotting Cell [419 336   0   0 386 407   0] at column 429...
# Plotting Cell [  0 331   0 371 321 242   0] at column 430...
# Plotting Cell [  0 361 379 402 361   0   0] at column 431...
# Plotting Cell [  0 379 342 356   0 384   0] at column 432...
# Plotting Cell [  0   0   0  66 188 156 139] at column 433...
# Plotting Cell [  0   0 304 310   0 374 367] at column 434...
# Plotting Cell [  0   0 364 410   0 322 368] at column 435...
# Plotting Cell [  0   0   0 232 199 222 218] at column 436...
# Plotting Cell [227   0 344 113   0 251   0] at column 437...
# Plotting Cell [  0   0 327 157 328 279   0] at column 438...
# Plotting Cell [  0   0 260 209   0  33  53] at column 439...
# Plotting Cell [  0 383 378 331 326   0   0] at column 440...
# Plotting Cell [  0   0 218   0 249 153 121] at column 441...
# Plotting Cell [  0   0 157 253 216 178   0] at column 442...
# Plotting Cell [  0 120  99   0  84   0  38] at column 443...
# Plotting Cell [281 316 285   0   0  61   0] at column 444...
# Plotting Cell [  0   0  32 155 166 246   0] at column 445...
# Plotting Cell [ 0 15  4  2 31  0  0] at column 446...
# Plotting Cell [  0  82 261 205   0 191   0] at column 447...
# Plotting Cell [  0   0   0 395 360 366 353] at column 448...
# Plotting Cell [  0   0 404 413 373   0 336] at column 449...
# Plotting Cell [  0   0   0 259 163 189 186] at column 450...
# Plotting Cell [418 371 245   0   0 317   0] at column 451...
# Plotting Cell [475 422 421 428   0   0   0] at column 452...
# Plotting Cell [363 377   0   0   0 401 398] at column 453...
# Plotting Cell [316 229 366 363   0   0   0] at column 454...
# Plotting Cell [372 284 288   0   0 280   0] at column 455...
# Plotting Cell [342   0 338 405 383   0   0] at column 456...
# Plotting Cell [385 366 362   0 342   0   0] at column 457...
# Plotting Cell [390 372   0   0 247 241   0] at column 458...
# Plotting Cell [392 402 367   0   0 419   0] at column 459...
# Plotting Cell [335 256   0 355 288   0   0] at column 460...
# Plotting Cell [  0 288 313 364   0 365   0] at column 461...
# Plotting Cell [331 345 388 278   0   0   0] at column 462...
# Plotting Cell [326   0 146   0 320   0 343] at column 463...
# Plotting Cell [339 260   0 234   0 295   0] at column 464...
# Plotting Cell [285 300   0 185 138   0   0] at column 465...
# Plotting Cell [282   0 224   0   0 314 357] at column 466...
# Plotting Cell [288 293   0 362   0   0 395] at column 467...
# Plotting Cell [  0   0   0 426 405 392   0] at column 468...
# Plotting Cell [155   0   0 248   0 335   0] at column 469...
# Plotting Cell [ 84  97   0   0 152   0   0] at column 470...
# Plotting Cell [  0 400   0 352   0 342   0] at column 471...
# Plotting Cell [  0   0 389   0   0 152 240] at column 472...
# Plotting Cell [  0 395 292   0   0   0 422] at column 473...
# Plotting Cell [  0   0 397   0 385 362   0] at column 474...
# Plotting Cell [  0 245   0   0 220 275   0] at column 475...
# Plotting Cell [349   0 244   0   0 315   0] at column 476...
# Plotting Cell [  0 392 337   0   0 126   0] at column 477...
# Plotting Cell [  0 409 410   0 408   0   0] at column 478...
# Plotting Cell [  0 342 323   0   0 303   0] at column 479...
# Plotting Cell [ 13   0   0  52   0 158   0] at column 480...
# Plotting Cell [  0   0 405 408 378   0   0] at column 481...
# Plotting Cell [355   0 179   0   0  83   0] at column 482...
# Plotting Cell [  0 302 164   0 177   0   0] at column 483...
# Plotting Cell [  0   0   0  25 222   0 222] at column 484...
# Plotting Cell [  0 301   0 178   0   0 386] at column 485...
# Plotting Cell [ 87  34 128   0   0   0   0] at column 486...
# Plotting Cell [153 193   0   0 230   0   0] at column 487...
# Plotting Cell [  0   0   0 415 401   0 348] at column 488...
# Plotting Cell [404   0   0 422   0   0 407] at column 489...
# Plotting Cell [  0   0   0 133 298  65   0] at column 490...
# Plotting Cell [  0   0   0 330   0 326 327] at column 491...
# Plotting Cell [311   0   0 128   0   0  48] at column 492...
# Plotting Cell [314   0   0   0 400   0 276] at column 493...
# Plotting Cell [  0   0   0 324   0 250 216] at column 494...
# Plotting Cell [  0   0 173  51  71   0   0] at column 495...
# Plotting Cell [317   0 340   0   0   0 385] at column 496...
# Plotting Cell [  2   0   0   0  33 128   0] at column 497...
# Plotting Cell [  0   0   0 347   0 202 376] at column 498...
# Plotting Cell [309 305   0   0   0   0 266] at column 499...
# Plotting Cell [  0 427 425 430   0   0   0] at column 500...
# Plotting Cell [177   0   0   0  91 215   0] at column 501...
# Plotting Cell [303   0   0 127   0   0 143] at column 502...
# Plotting Cell [340 364 298   0   0   0   0] at column 503...
# Plotting Cell [  0   0   0  36 128   0 161] at column 504...
# Plotting Cell [147 328   0   0   0   0 331] at column 505...
# Plotting Cell [341   0   0 246   0 123   0] at column 506...
# Plotting Cell [415 338   0 338   0   0   0] at column 507...
# Plotting Cell [417  87 176   0   0   0   0] at column 508...
# Plotting Cell [  0 243   0 152   0 293   0] at column 509...
# Plotting Cell [34 25 11  0  0  0  0] at column 510...
# Plotting Cell [468   0   0   0 183 402   0] at column 511...
# Plotting Cell [466   0   0   0 353   0 382] at column 512...
# Plotting Cell [464 413 409   0   0   0   0] at column 513...
# Plotting Cell [ 57 179  94   0   0   0   0] at column 514...
# Plotting Cell [460 396 401   0   0   0   0] at column 515...
# Plotting Cell [211   0   0   0 302   0 245] at column 516...
# Plotting Cell [  0   0  55 148   0  11   0] at column 517...
# Plotting Cell [452 389 403   0   0   0   0] at column 518...
# Plotting Cell [400   0 396   0   0   0 269] at column 519...
# Plotting Cell [  0   0   0  13   0  59 162] at column 520...
# Plotting Cell [473 411   0 414   0   0   0] at column 521...
# Plotting Cell [  0   0   0 166   0 258 128] at column 522...
# Plotting Cell [406   0   0 300   0 403   0] at column 523...
# Plotting Cell [429 429 417   0   0   0   0] at column 524...
# Plotting Cell [  0 296   0   0   0 268 185] at column 525...
# Plotting Cell [428 358   0   0   0   0 311] at column 526...
# Plotting Cell [427   0   0 304   0   0 148] at column 527...
# Plotting Cell [407 360 398   0   0   0   0] at column 528...
# Plotting Cell [420   0 399   0 404   0   0] at column 529...
# Plotting Cell [  0   0   0  39   0 332 319] at column 530...
# Plotting Cell [200   0   0 322 304   0   0] at column 531...
# Plotting Cell [470 406   0   0   0 355   0] at column 532...
# Plotting Cell [27  0  0  0  0 50 49] at column 533...
# Plotting Cell [  0 228  82   0   0   0 274] at column 534...
# Plotting Cell [378 315   0 305   0   0   0] at column 535...
# Plotting Cell [  0   0   0 425 415   0 338] at column 536...
# Plotting Cell [  0 195 225   0 333   0   0] at column 537...
# Plotting Cell [  0   0 239   0   0 105 292] at column 538...
# Plotting Cell [481   0 407 396   0   0   0] at column 539...
# Plotting Cell [194   0   0   0  65   0 227] at column 540...
# Plotting Cell [17 46  0  0  0  0 81] at column 541...
# Plotting Cell [  0  31   0   0  79 102   0] at column 542...
# Plotting Cell [  0 139 194   0   0   0 126] at column 543...
# Plotting Cell [ 18 155   0   0   0   0 304] at column 544...
# Plotting Cell [  0 334   0   0   0 380   0] at column 545...
# Plotting Cell [  0   0   0   0 282   0 326] at column 546...
# Plotting Cell [  0   0   0   0 410   0 412] at column 547...
# Plotting Cell [  0   0   0   0 338   0 346] at column 548...
# Plotting Cell [  0   0   0   0 226   0 334] at column 549...
# Plotting Cell [  0   0   0  33   0   0 275] at column 550...
# Plotting Cell [  0   0   0   0   0 296 164] at column 551...
# Plotting Cell [  0   0   0   9   0   0 176] at column 552...
# Plotting Cell [  0   0   0 254   0   0 291] at column 553...
# Plotting Cell [  0   0   0   0   0 162 190] at column 554...
# Plotting Cell [  0   0   0   0   0 198 242] at column 555...
# Plotting Cell [  0   0   0   0   0 185  95] at column 556...
# Plotting Cell [  0   0   0 358   0   0 387] at column 557...
# Plotting Cell [  0   0   0 345   0 395   0] at column 558...
# Plotting Cell [  0   0   0   0   0 140 296] at column 559...
# Plotting Cell [ 0  0  0 73 36  0  0] at column 560...
# Plotting Cell [  0   0   0   0 117   0 309] at column 561...
# Plotting Cell [  0   0   0   0 347 286   0] at column 562...
# Plotting Cell [  0   0   0   0 126   0 172] at column 563...
# Plotting Cell [  0   0   0 433   0   0 420] at column 564...
# Plotting Cell [  0   0   0   0   3 119   0] at column 565...
# Plotting Cell [  0   0   0   0 416   0 421] at column 566...
# Plotting Cell [  0   0   0   0 406   0 384] at column 567...
# Plotting Cell [  0   0   0 424 356   0   0] at column 568...
